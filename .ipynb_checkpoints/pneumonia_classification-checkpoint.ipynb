# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras_preprocessing
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# path selections
train_dir = 'dataset_xray_images/train'
validation_dir = 'dataset_xray_images/val'

# %%
training_datagen = ImageDataGenerator(
    rescale = 1./255,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2)

validation_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = training_datagen.flow_from_directory(
    train_dir,
    target_size=(80,80),
    class_mode='categorical',
    batch_size=64
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(80,80),
    class_mode='categorical',
    batch_size=64
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
model = tf.keras.Sequential()

model.add(layers.Conv2D(64, (3,3), activation='relu', input_shape=(80, 80, 3)))
model.add(layers.MaxPooling2D(2, 2))
          
model.add(layers.Conv2D(32, (3,3), activation='relu'))
model.add(layers.MaxPooling2D(2, 2))
          
model.add(layers.Conv2D(128, (3,3), activation='relu'))
model.add(layers.MaxPooling2D(2, 2))
          
model.add(layers.Conv2D(128, (3,3), activation='relu'))
model.add(layers.MaxPooling2D(2, 2))
          
model.add(layers.Flatten())
model.add(layers.Dropout(0.2))

model.add(layers.Dense(512, activation='relu'))
          
model.add(layers.Dense(264, activation='relu'))
          
model.add(layers.Dense(2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 78, 78, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 39, 39, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 37, 37, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 18, 18, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       36992
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               590336
# _________________________________________________________________
# dense_1 (Dense)              (None, 264)               135432
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 530
# =================================================================
# Total params: 931,130
# Trainable params: 931,130
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
history = model.fit(train_generator, epochs=45, validation_data = validation_generator, verbose = 1)
# Out:
# Epoch 1/45
# 82/82 [==============================] - 170s 2s/step - loss: 0.5955 - accuracy: 0.7347 - val_loss: 0.6399 - val_accuracy: 0.6330
# Epoch 2/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.4960 - accuracy: 0.7697 - val_loss: 0.5618 - val_accuracy: 0.6907
# Epoch 3/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.4008 - accuracy: 0.8108 - val_loss: 0.4986 - val_accuracy: 0.7676
# Epoch 4/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.3345 - accuracy: 0.8576 - val_loss: 0.4520 - val_accuracy: 0.7997
# Epoch 5/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.3062 - accuracy: 0.8669 - val_loss: 0.2841 - val_accuracy: 0.8846
# Epoch 6/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.2753 - accuracy: 0.8823 - val_loss: 0.2898 - val_accuracy: 0.8798
# Epoch 7/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.2431 - accuracy: 0.9009 - val_loss: 0.4156 - val_accuracy: 0.8638
# Epoch 8/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.2417 - accuracy: 0.9047 - val_loss: 0.3873 - val_accuracy: 0.8606
# Epoch 9/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.2246 - accuracy: 0.9099 - val_loss: 0.3211 - val_accuracy: 0.9054
# Epoch 10/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.2235 - accuracy: 0.9166 - val_loss: 0.2753 - val_accuracy: 0.9215
# Epoch 11/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1940 - accuracy: 0.9206 - val_loss: 0.4900 - val_accuracy: 0.8686
# Epoch 12/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1947 - accuracy: 0.9268 - val_loss: 0.5793 - val_accuracy: 0.8686
# Epoch 13/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1935 - accuracy: 0.9229 - val_loss: 0.9523 - val_accuracy: 0.7051
# Epoch 14/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1727 - accuracy: 0.9289 - val_loss: 0.2888 - val_accuracy: 0.9247
# Epoch 15/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1794 - accuracy: 0.9360 - val_loss: 0.2529 - val_accuracy: 0.9231
# Epoch 16/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1519 - accuracy: 0.9423 - val_loss: 0.5511 - val_accuracy: 0.8878
# Epoch 17/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1734 - accuracy: 0.9363 - val_loss: 0.1914 - val_accuracy: 0.9343
# Epoch 18/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1612 - accuracy: 0.9381 - val_loss: 0.3630 - val_accuracy: 0.8798
# Epoch 19/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1444 - accuracy: 0.9429 - val_loss: 0.2303 - val_accuracy: 0.9327
# Epoch 20/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1495 - accuracy: 0.9475 - val_loss: 0.3296 - val_accuracy: 0.8910
# Epoch 21/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1417 - accuracy: 0.9461 - val_loss: 0.2951 - val_accuracy: 0.9135
# Epoch 22/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1352 - accuracy: 0.9463 - val_loss: 0.4564 - val_accuracy: 0.8958
# Epoch 23/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1459 - accuracy: 0.9454 - val_loss: 0.4484 - val_accuracy: 0.8830
# Epoch 24/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1344 - accuracy: 0.9498 - val_loss: 0.4446 - val_accuracy: 0.8237
# Epoch 25/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1368 - accuracy: 0.9507 - val_loss: 0.3823 - val_accuracy: 0.8878
# Epoch 26/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1263 - accuracy: 0.9538 - val_loss: 0.2970 - val_accuracy: 0.9343
# Epoch 27/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1432 - accuracy: 0.9523 - val_loss: 0.4025 - val_accuracy: 0.8910
# Epoch 28/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1210 - accuracy: 0.9567 - val_loss: 0.2581 - val_accuracy: 0.9295
# Epoch 29/45
# 82/82 [==============================] - 133s 2s/step - loss: 0.1271 - accuracy: 0.9549 - val_loss: 0.3394 - val_accuracy: 0.9038
# Epoch 30/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1235 - accuracy: 0.9549 - val_loss: 0.2951 - val_accuracy: 0.9311
# Epoch 31/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1279 - accuracy: 0.9559 - val_loss: 0.2106 - val_accuracy: 0.9471
# Epoch 32/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1237 - accuracy: 0.9530 - val_loss: 0.2560 - val_accuracy: 0.9455
# Epoch 33/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1306 - accuracy: 0.9561 - val_loss: 0.2117 - val_accuracy: 0.9439
# Epoch 34/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1174 - accuracy: 0.9544 - val_loss: 0.4868 - val_accuracy: 0.8910
# Epoch 35/45
# 82/82 [==============================] - 129s 2s/step - loss: 0.1236 - accuracy: 0.9580 - val_loss: 0.3060 - val_accuracy: 0.9151
# Epoch 36/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1182 - accuracy: 0.9571 - val_loss: 0.3519 - val_accuracy: 0.9103
# Epoch 37/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1238 - accuracy: 0.9582 - val_loss: 0.2700 - val_accuracy: 0.9423
# Epoch 38/45
# 82/82 [==============================] - 131s 2s/step - loss: 0.1221 - accuracy: 0.9634 - val_loss: 0.3670 - val_accuracy: 0.9247
# Epoch 39/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1201 - accuracy: 0.9582 - val_loss: 0.2457 - val_accuracy: 0.9375
# Epoch 40/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1205 - accuracy: 0.9594 - val_loss: 0.3046 - val_accuracy: 0.9263
# Epoch 41/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1081 - accuracy: 0.9618 - val_loss: 0.3957 - val_accuracy: 0.9391
# Epoch 42/45
# 82/82 [==============================] - 131s 2s/step - loss: 0.1200 - accuracy: 0.9569 - val_loss: 0.3219 - val_accuracy: 0.9199
# Epoch 43/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1128 - accuracy: 0.9571 - val_loss: 0.4331 - val_accuracy: 0.9423
# Epoch 44/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1142 - accuracy: 0.9607 - val_loss: 0.2842 - val_accuracy: 0.9311
# Epoch 45/45
# 82/82 [==============================] - 130s 2s/step - loss: 0.1248 - accuracy: 0.9553 - val_loss: 0.3112 - val_accuracy: 0.9295

# %%
img_path_norm = 'dataset_xray_images/test/NORMAL/NORMAL2-IM-1436-0001.jpeg'
img = mpimg.imread(img_path)
plt.title("Normal X-ray Image")
plt.imshow(img)
plt.show()

img_path_pneumonia = 'dataset_xray_images/test/PNEUMONIA/person1949_bacteria_4880.jpeg'
img = mpimg.imread(img_path)
plt.title("Pneumonia X-ray Image")
plt.imshow(img)
plt.show()

# %%
# taking testing image from test set
path_im_pneumonia = 'dataset_xray_images/test/PNEUMONIA/person1949_bacteria_4880.jpeg'
path_im_normal = 'dataset_xray_images/test/NORMAL/NORMAL2-IM-1436-0001.jpeg'

img1 = image.load_img(path_im_pneumonia, target_size=(80, 80))
img2 = image.load_img(path_im_normal, target_size=(80, 80))

# converting to array
imToArr1 = image.img_to_array(img1)
imToArr2 = image.img_to_array(img2)

# expanding layer
imToArr1 = np.expand_dims(imToArr1, axis=0)
imToArr2 = np.expand_dims(imToArr2, axis=0)

# stacking images
images = np.vstack([imToArr1,imToArr2])

#predicting
predicted_class = model.predict(images, batch_size=1)
print(predicted_class)
# Out:
# [[0. 1.]
#  [1. 0.]]
